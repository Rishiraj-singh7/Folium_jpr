# %% [markdown]
# # Python Interactive Maps with Folium

# %% [markdown]
# Documentation

# %%
from IPython.display import IFrame
documentation = IFrame(src='https://python-visualization.github.io/folium/', width=1000, height=500)
display(documentation)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://python-visualization.github.io/folium/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Imports

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.6 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/98.6 kB ? eta -:--:--
#      ----------------------- -------------- 61.4/98.6 kB 648.1 kB/s eta 0:00:01
#      -------------------------------------- 98.6/98.6 kB 803.2 kB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\rishi\anaconda3\lib\site-packages (from geocoder) (8.0.4)
# Requirement already satisfied: future in c:\users\rishi\anaconda3\lib\site-packages (from geocoder) (0.18.3)
# Collecting ratelim (from geocoder)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: requests in c:\users\rishi\anaconda3\lib\site-packages (from geocoder) (2.31.0)
# Requirement already satisfied: six in c:\users\rishi\anaconda3\lib\site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: colorama in c:\users\rishi\anaconda3\lib\site-packages (from click->geocoder) (0.4.6)
# Requirement already satisfied: decorator in c:\users\rishi\anaconda3\lib\site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rishi\anaconda3\lib\site-packages (from requests->geocoder) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishi\anaconda3\lib\site-packages (from requests->geocoder) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishi\anaconda3\lib\site-packages (from requests->geocoder) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishi\anaconda3\lib\site-packages (from requests->geocoder) (2023.7.22)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023512655990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/geocoder/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023512653690>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/geocoder/
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000235126F1F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000235126F2510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------- ------------------- 20.5/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 940.1 kB/s eta 0:00:00
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ------------- -------------------------- 41.0/125.4 kB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 112.6/125.4 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000292F1F78550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata

# %%
# !pip install vega_datasets
# Out:
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      ---------------------------------------- 0.0/210.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/210.8 kB ? eta -:--:--
#      ------- ----------------------------- 41.0/210.8 kB 393.8 kB/s eta 0:00:01
#      ---------------- -------------------- 92.2/210.8 kB 751.6 kB/s eta 0:00:01
#      ------------------------ ----------- 143.4/210.8 kB 853.3 kB/s eta 0:00:01
#      ------------------------------------ 210.8/210.8 kB 988.1 kB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\rishi\anaconda3\lib\site-packages (from vega_datasets) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rishi\anaconda3\lib\site-packages (from pandas->vega_datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rishi\anaconda3\lib\site-packages (from pandas->vega_datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rishi\anaconda3\lib\site-packages (from pandas->vega_datasets) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\rishi\anaconda3\lib\site-packages (from pandas->vega_datasets) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\rishi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->vega_datasets) (1.16.0)
# Installing collected packages: vega_datasets
# Successfully installed vega_datasets-0.9.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002BD3C877190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/e6/9f/ca52771fe972e0dcc5167fedb609940e01516066938ff2ee28b273ae4f29/vega_datasets-0.9.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002BD3C877910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/e6/9f/ca52771fe972e0dcc5167fedb609940e01516066938ff2ee28b273ae4f29/vega_datasets-0.9.0-py3-none-any.whl

# %%
import folium
from folium import plugins
import ipywidgets
import geocoder
import geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds

# %% [markdown]
# # Basic Maps

# %%
# basic map
# zoom and pan

folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f65375196d2b689a5169082ce10407b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f65375196d2b689a5169082ce10407b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f65375196d2b689a5169082ce10407b = L.map(
#                 &quot;map_0f65375196d2b689a5169082ce10407b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34f6b6f18904ac2087779e74137103c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_34f6b6f18904ac2087779e74137103c0.addTo(map_0f65375196d2b689a5169082ce10407b);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# map with location start point, zoom level, size, and distance scale
# zoom in by using a larger number for zoom_start

map1 = folium.Map(location=[39.739192, -104.990337], zoom_start=12, width=500, height=300, control_scale=True)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5826d72750fd686382ae108d03fe05ac {
#                     position: relative;
#                     width: 500.0px;
#                     height: 300.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5826d72750fd686382ae108d03fe05ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5826d72750fd686382ae108d03fe05ac = L.map(
#                 &quot;map_5826d72750fd686382ae108d03fe05ac&quot;,
#                 {
#                     center: [39.739192, -104.990337],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5826d72750fd686382ae108d03fe05ac);
#
#
#
#
#
#             var tile_layer_fe46301f7218a90c74b0feef64b35750 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_fe46301f7218a90c74b0feef64b35750.addTo(map_5826d72750fd686382ae108d03fe05ac);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# another way to change map size

from branca.element import Figure

fig = Figure(width=500, height=300)
fig.add_child(map1)
fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5826d72750fd686382ae108d03fe05ac {
#                     position: relative;
#                     width: 500.0px;
#                     height: 300.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5826d72750fd686382ae108d03fe05ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5826d72750fd686382ae108d03fe05ac = L.map(
#                 &quot;map_5826d72750fd686382ae108d03fe05ac&quot;,
#                 {
#                     center: [39.739192, -104.990337],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5826d72750fd686382ae108d03fe05ac);
#
#
#
#
#
#             var tile_layer_fe46301f7218a90c74b0feef64b35750 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_fe46301f7218a90c74b0feef64b35750.addTo(map_5826d72750fd686382ae108d03fe05ac);
# &lt;/script&gt;
# &lt;/html&gt;" width="500" height="300"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# # Save Map

# %%
#  # make a map
# map2 = folium.Map(location=[39.739192, -104.990337], zoom_start=8)

# # put in path.html and save it
# map2.save('/Users/Desktop/map2.html')

# %% [markdown]
# # Map Types

# %%
# show map types using ipywidgets

# widget
select_widget=ipywidgets.Select(
    options=['Open Street Map', 'Terrain', 'Toner', 'Watercolor', 'Positron', 'Dark Matter'],
    value='Open Street Map',
    description='Map Type:',
    disabled=False)

# widget function
def select(map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location=[39.739192, -104.990337], zoom_start=12, height=500))
    if map_type == 'Terrain':
        display(folium.Map(location=[39.739192, -104.990337], tiles='Stamen Terrain', zoom_start=12, height=400))
    if map_type == 'Toner':
        display(folium.Map(location=[39.739192, -104.990337], tiles='Stamen Toner', zoom_start=12, height=400))
    if map_type == 'Watercolor':
        display(folium.Map(location=[39.739192, -104.990337], tiles='Stamen Watercolor', zoom_start=12, height=400))
    if map_type == 'Positron':
        display(folium.Map(location=[39.739192, -104.990337], tiles='CartoDB Positron', zoom_start=12, height=400))
    if map_type == 'Dark Matter':
        display(folium.Map(location=[39.739192, -104.990337], tiles='CartoDB Dark_Matter', zoom_start=12, height=400))
        
# interaction between widgets and function    
ipywidgets.interact(select, map_type=select_widget)
# Out:
# interactive(children=(Select(description='Map Type:', options=('Open Street Map', 'Terrain', 'Toner', 'Waterco…
# <function __main__.select(map_type)>

# %%
# show map types using layer control

# # map
# map_layer_control = folium.Map(location=[38, -98], zoom_start=2)

# # add tiles to map
# folium.raster_layers.TileLayer('Open Street Map').add_to(map_layer_control)
# folium.raster_layers.TileLayer('Stamen Terrain').add_to(map_layer_control)
# folium.raster_layers.TileLayer('Stamen Toner').add_to(map_layer_control)
# folium.raster_layers.TileLayer('Stamen Watercolor').add_to(map_layer_control)
# folium.raster_layers.TileLayer('CartoDB Positron').add_to(map_layer_control)
# folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(map_layer_control)

# # add layer control to show different maps
# folium.LayerControl().add_to(map_layer_control)

# # display map
# map_layer_control

# %%
# mini map, scroll zoom toggle button, full screen

# map
map_with_mini = folium.Map(location=(39, -100), zoom_start=7)

# plugin for mini map
minimap = plugins.MiniMap(toggle_display=True)

# add minimap to map
map_with_mini.add_child(minimap)

# add scroll zoom toggler to map
plugins.ScrollZoomToggler().add_to(map_with_mini)

# add full screen button to map
plugins.Fullscreen(position='topright').add_to(map_with_mini)

# display map
map_with_mini
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af0851dbb86c6af61612dda344cde315 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_363867302396420ab61708eb763d2448 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af0851dbb86c6af61612dda344cde315&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_363867302396420ab61708eb763d2448&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_af0851dbb86c6af61612dda344cde315.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af0851dbb86c6af61612dda344cde315 = L.map(
#                 &quot;map_af0851dbb86c6af61612dda344cde315&quot;,
#                 {
#                     center: [39.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f35eed001fad45d36c46e615f6f228a3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_f35eed001fad45d36c46e615f6f228a3.addTo(map_af0851dbb86c6af61612dda344cde315);
#
#             var tile_layer_850baf87175517fc161037d3c5ac95fb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_5bd68ea1d5cfefb80cc0f2695b91e077 = new L.Control.MiniMap(
#                 tile_layer_850baf87175517fc161037d3c5ac95fb,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_af0851dbb86c6af61612dda344cde315.addControl(mini_map_5bd68ea1d5cfefb80cc0f2695b91e077);
#
#
#             map_af0851dbb86c6af61612dda344cde315.scrollEnabled = true;
#
#             map_af0851dbb86c6af61612dda344cde315.toggleScroll = function() {
#                 if (this.scrollEnabled) {
#                     this.scrollEnabled = false;
#                     this.scrollWheelZoom.disable();
#                 } else {
#                     this.scrollEnabled = true;
#                     this.scrollWheelZoom.enable();
#                 }
#             };
#             map_af0851dbb86c6af61612dda344cde315.toggleScroll();
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_af0851dbb86c6af61612dda344cde315);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Markers

# %%
# geocode address and place marker on map

# map
map_zoo = folium.Map(location=[32.744524, -117.150302], zoom_start=14)

# get location information for address
address = geocoder.osm('2920 Zoo Dr, San Diego, CA 92101')

# address latitude and longitude
address_latlng = [address.lat, address.lng]

# add marker to map
folium.Marker(address_latlng, popup='San Diego Zoo', tooltip='click').add_to(map_zoo)

# display map
map_zoo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd47b53189e38d7880a444982383fd54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd47b53189e38d7880a444982383fd54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd47b53189e38d7880a444982383fd54 = L.map(
#                 &quot;map_cd47b53189e38d7880a444982383fd54&quot;,
#                 {
#                     center: [32.744524, -117.150302],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ae8d8c1e109c79fcc06acf7487e65be = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_7ae8d8c1e109c79fcc06acf7487e65be.addTo(map_cd47b53189e38d7880a444982383fd54);
#
#             var marker_f78b4be7c301547944ec63f057f31cac = L.marker(
#                 [32.73598735, -117.15065415761478],
#                 {}
#             ).addTo(map_cd47b53189e38d7880a444982383fd54);
#
#
#         var popup_09c6f33ca455526886b3e19c3321ec3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d46359b0d7617702075b6519278e28b4 = $(`&lt;div id=&quot;html_d46359b0d7617702075b6519278e28b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Diego Zoo&lt;/div&gt;`)[0];
#                 popup_09c6f33ca455526886b3e19c3321ec3b.setContent(html_d46359b0d7617702075b6519278e28b4);
#
#
#
#         marker_f78b4be7c301547944ec63f057f31cac.bindPopup(popup_09c6f33ca455526886b3e19c3321ec3b)
#         ;
#
#
#
#
#             marker_f78b4be7c301547944ec63f057f31cac.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# airports dataframe using vega_datasets
airports = vds.airports()
airports = airports[:25]
airports.head()
# Out:
#   iata                  name              city state country   latitude  \
# 0  00M               Thigpen       Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#     longitude
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %%
# multiple markers using dataframe
# there is an example below using apply function instead of loop

# create map
map_airports = folium.Map(location=[38, -98], zoom_start=4)

# plot airport locations
for (index, row) in airports.iterrows():
    folium.Marker(location=[row.loc['latitude'], row.loc['longitude']], 
                  popup=row.loc['name'] + ' ' + row.loc['city'] + ' ' + row.loc['state'], 
                  tooltip='click').add_to(map_airports)
    
# display map    
map_airports
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f813e09a893c30f1b4a87eabd8c2b76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f813e09a893c30f1b4a87eabd8c2b76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f813e09a893c30f1b4a87eabd8c2b76 = L.map(
#                 &quot;map_5f813e09a893c30f1b4a87eabd8c2b76&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_272d63b992af7f30b8822472437aeb45 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_272d63b992af7f30b8822472437aeb45.addTo(map_5f813e09a893c30f1b4a87eabd8c2b76);
#
#             var marker_b455a040c2f37972d1ca1764803ef2b2 = L.marker(
#                 [31.95376472, -89.23450472],
#                 {}
#             ).addTo(map_5f813e09a893c30f1b4a87eabd8c2b76);
#
#
#         var popup_86252204eb4c003ea8c8cbb06cf5f2f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad62bb123e463ae2657fa37f6ac4e639 = $(`&lt;div id=&quot;html_ad62bb123e463ae2657fa37f6ac4e639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen Bay Springs MS&lt;/div&gt;`)[0];
#                 popup_86252204eb4c003ea8c8cbb06cf5f2f7.setContent(html_ad62bb123e463ae2657fa37f6ac4e639);
#
#
#
#         marker_b455a040c2f37972d1ca1764803ef2b2.bindPopup(popup_86252204eb4c003ea8c8cbb06cf5f2f7)
#         ;
#
#
#
#
#             marker_b455a040c2f37972d1ca1764803ef2b2.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a91688c005518ba973e143a8346e1375 = L.marker(
#                 [30.68586111, -95.01792778],
#                 {}
#             ).addTo(map_5f813e09a893c30f1b4a87eabd8c2b76);
#
#
#         var popup_7805db563a4981250638572d54746699 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6014191756d1a397f95c36480a51b74d = $(`&lt;div id=&quot;html_6014191756d1a397f95c36480a51b74d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal Livingston TX&lt;/div&gt;`)[0];
#                 popup_7805db563a4981250638572d54746699.setContent(html_6014191756d1a397f95c36480a51b74d);
#
#
#
#         marker_a91688c005518ba973e143a8346e1375.bindPopup(popup_7805db563a4981250638572d54746699)
#         ;
#
#
#
#
#             marker_a91688c005518ba973e143a8346e1375.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2cc23da9fb73af32737d31a4f90700e = L.marker(
#                 [38.94574889, -104.5698933],
#                 {}
#             ).addTo(map_5f813e09a893c30f1b4a87eabd8c2b76);
#
#
#         var popup_e13555515301d3e2f3ce02ff81aa02d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e31b32f6532ae63ab675019695486a7f = $(`&lt;div id=&quot;html_e31b32f6532ae63ab675019695486a7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake Colorado Springs CO&lt;/div&gt;`)[0];
#                 popup_e13555515301d3e2f3ce02ff81aa02d1.setContent(html_e31b32f6532ae63ab675019695486a7f);
#
#
#
#         marker_b2cc23da9fb73af32737d31a4f90700e.bindPopup(popup_e13555515301d3e2f3ce02ff81aa02d1)
#         ;
#
#
#
#
#             marker_b2cc23da9fb73af32737d31a4f90700e.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_264e5964ae0f4dd34460ddcbf31d3a12 = L.marker(
#                 [42.74134667, -78.05208056],
#                 {}
#             ).addTo(map_5f813e09a893c30f1b4a87eabd8c2b76);
#
#
#         var popup_24214148b055a804581176ddbbdbc18c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fbbba0a0b623a7bb0bd5c71f0ba5834 = $(`&lt;div id=&quot;html_8fbbba0a0b623a7bb0bd5c71f0ba5834&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw Perry NY&lt;/div&gt;`)[0];
#                 popup_24214148b055a804581176ddbbdbc18c.setContent(html_8fbbba0a0b623a7bb0bd5c71f0ba5834);
#
#
#
#         marker_264e5964ae0f4dd34460ddcbf31d3a12.bindPopup(popup_24214148b055a804581176ddbbdbc18c)
#         ;
#
#
#
#
#             marker_264e5964ae0f4dd34460ddcbf31d3a12.bindTooltip(
#                 `&lt;div&gt;

# %%
for (index, row) in airports.iterrows():
    # print(row.loc['name'])
    # print(index,row['name'])
    print(index,row)
# Out:
# 0 iata                 00M
# name             Thigpen
# city         Bay Springs
# state                 MS
# country              USA
# latitude       31.953765
# longitude     -89.234505
# Name: 0, dtype: object
# 1 iata                          00R
# name         Livingston Municipal
# city                   Livingston
# state                          TX
# country                       USA
# latitude                30.685861
# longitude              -95.017928
# Name: 1, dtype: object
# 2 iata                      00V
# name              Meadow Lake
# city         Colorado Springs
# state                      CO
# country                   USA
# latitude            38.945749
# longitude         -104.569893
# Name: 2, dtype: object
# 3 iata                  01G
# name         Perry-Warsaw
# city                Perry
# state                  NY
# country               USA
# latitude        42.741347
# longitude      -78.052081
# Name: 3, dtype: object
# 4 iata                      01J
# name         Hilliard Airpark
# city                 Hilliard
# state                      FL
# country                   USA
# latitude            30.688012
# longitude          -81.905944
# Name: 4, dtype: object
# 5 iata                       01M
# name         Tishomingo County
# city                   Belmont
# state                       MS
# country                    USA
# latitude             34.491667
# longitude           -88.201111
# Name: 5, dtype: object
# 6 iata                02A
# name         Gragg-Wade
# city            Clanton
# state                AL
# country             USA
# latitude      32.850487
# longitude    -86.611453
# Name: 6, dtype: object
# 7 iata                02C
# name            Capitol
# city         Brookfield
# state                WI
# country             USA
# latitude       43.08751
# longitude    -88.177869
# Name: 7, dtype: object
# 8 iata                       02G
# name         Columbiana County
# city            East Liverpool
# state                       OH
# country                    USA
# latitude             40.673313
# longitude           -80.641406
# Name: 8, dtype: object
# 9 iata                      03D
# name         Memphis Memorial
# city                  Memphis
# state                      MO
# country                   USA
# latitude            40.447259
# longitude          -92.226961
# Name: 9, dtype: object
# 10 iata                    04M
# name         Calhoun County
# city              Pittsboro
# state                    MS
# country                 USA
# latitude          33.930112
# longitude        -89.342852
# Name: 10, dtype: object
# 11 iata                      04Y
# name         Hawley Municipal
# city                   Hawley
# state                      MN
# country                   USA
# latitude            46.883849
# longitude          -96.350899
# Name: 11, dtype: object
# 12 iata                           05C
# name         Griffith-Merrillville
# city                      Griffith
# state                           IN
# country                        USA
# latitude                 41.519619
# longitude               -87.401093
# Name: 12, dtype: object
# 13 iata                              05F
# name         Gatesville - City/County
# city                       Gatesville
# state                              TX
# country                           USA
# latitude                    31.421276
# longitude                  -97.796968
# Name: 13, dtype: object
# 14 iata               05U
# name            Eureka
# city            Eureka
# state               NV
# country            USA
# latitude     39.604167
# longitude   -116.00506
# Name: 14, dtype: object
# 15 iata                      06A
# name         Moton  Municipal
# city                 Tuskegee
# state                      AL
# country                   USA
# latitude            32.460472
# longitude          -85.680036
# Name: 15, dtype: object
# 16 iata                        06C
# name                 Schaumburg
# city         Chicago/Schaumburg
# state                        IL
# country                     USA
# latitude              41.989341
# longitude            -88.101243
# Name: 16, dtype: object
# 17 iata                     06D
# name         Rolla Municipal
# city                   Rolla
# state                     ND
# country                  USA
# latitude           48.884341
# longitude         -99.620877
# Name: 17, dtype: object
# 18 iata                      06M
# name         Eupora Municipal
# city                   Eupora
# state                      MS
# country                   USA
# latitude            33.534566
# longitude          -89.312569
# Name: 18, dtype: object
# 19 iata                06N
# name            Randall
# city         Middletown
# state                NY
# country             USA
# latitude      41.431566
# longitude    -74.391917
# Name: 19, dtype: object
# 20 iata                    06U
# name         Jackpot/Hayden
# city                Jackpot
# state                    NV
# country                 USA
# latitude          41.976022
# longitude       -114.658091
# Name: 20, dtype: object
# 21 iata                   07C
# name         Dekalb County
# city                Auburn
# state                   IN
# country                USA
# latitude         41.307167
# longitude       -85.064333
# Name: 21, dtype: object
# 22 iata                          07F
# name         Gladewater Municipal
# city                   Gladewater
# state                          TX
# country                       USA
# latitude                32.528839
# longitude              -94.971746
# Name: 22, dtype: object
# 23 iata                   07G
# name         Fitch H Beach
# city             Charlotte
# state                   MI
# country                USA
# latitude         42.574509
# longitude       -84.811431
# Name: 23, dtype: object
# 24 iata                            07K
# name         Central City Municipal
# city                   Central City
# state                            NE
# country                         USA
# latitude                  41.116681
# longitude                -98.050336
# Name: 24, dtype: object

# %%
# markers with apply function

# map
map_airports2 = folium.Map(location=[38, -98], zoom_start=4)

# plot airport locations using apply
airports.apply(lambda row: folium.Marker(location=[row['latitude'], row['longitude']],
                                         popup=row['name']).add_to(map_airports2), axis=1)

# display map
map_airports2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fe3e63684907419c2d2a622ed19f835 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fe3e63684907419c2d2a622ed19f835&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fe3e63684907419c2d2a622ed19f835 = L.map(
#                 &quot;map_4fe3e63684907419c2d2a622ed19f835&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c82d14a88b9f3d8b8712390511ff44f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_c82d14a88b9f3d8b8712390511ff44f8.addTo(map_4fe3e63684907419c2d2a622ed19f835);
#
#             var marker_9bc09cbad9963889c8cccbc299c56566 = L.marker(
#                 [31.95376472, -89.23450472],
#                 {}
#             ).addTo(map_4fe3e63684907419c2d2a622ed19f835);
#
#
#         var popup_e5c8c135e206aa22217b310d9879284c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b0f999359d886b2ae0ddc9b86185354 = $(`&lt;div id=&quot;html_1b0f999359d886b2ae0ddc9b86185354&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen&lt;/div&gt;`)[0];
#                 popup_e5c8c135e206aa22217b310d9879284c.setContent(html_1b0f999359d886b2ae0ddc9b86185354);
#
#
#
#         marker_9bc09cbad9963889c8cccbc299c56566.bindPopup(popup_e5c8c135e206aa22217b310d9879284c)
#         ;
#
#
#
#
#             var marker_9b5b82d80cb939b7e3affc1fb21fc656 = L.marker(
#                 [30.68586111, -95.01792778],
#                 {}
#             ).addTo(map_4fe3e63684907419c2d2a622ed19f835);
#
#
#         var popup_50c0f6ef95646c3677faa92ad12c4566 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f373b1ffd302accaf00eaeffb963a887 = $(`&lt;div id=&quot;html_f373b1ffd302accaf00eaeffb963a887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal&lt;/div&gt;`)[0];
#                 popup_50c0f6ef95646c3677faa92ad12c4566.setContent(html_f373b1ffd302accaf00eaeffb963a887);
#
#
#
#         marker_9b5b82d80cb939b7e3affc1fb21fc656.bindPopup(popup_50c0f6ef95646c3677faa92ad12c4566)
#         ;
#
#
#
#
#             var marker_39c451b0ecfdb610d540b5a5a4dff75c = L.marker(
#                 [38.94574889, -104.5698933],
#                 {}
#             ).addTo(map_4fe3e63684907419c2d2a622ed19f835);
#
#
#         var popup_f68f03cee4568862a3fdbff7b95c7334 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f36870187e277b87a406047fc03dc5c4 = $(`&lt;div id=&quot;html_f36870187e277b87a406047fc03dc5c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake&lt;/div&gt;`)[0];
#                 popup_f68f03cee4568862a3fdbff7b95c7334.setContent(html_f36870187e277b87a406047fc03dc5c4);
#
#
#
#         marker_39c451b0ecfdb610d540b5a5a4dff75c.bindPopup(popup_f68f03cee4568862a3fdbff7b95c7334)
#         ;
#
#
#
#
#             var marker_e97aa1d2fc6b8584479cfc882c954821 = L.marker(
#                 [42.74134667, -78.05208056],
#                 {}
#             ).addTo(map_4fe3e63684907419c2d2a622ed19f835);
#
#
#         var popup_0cf21217bb6df64c77ed5a9f8810b78e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4b661c26630f87eff9a8fbf172aca34 = $(`&lt;div id=&quot;html_b4b661c26630f87eff9a8fbf172aca34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw&lt;/div&gt;`)[0];
#                 popup_0cf21217bb6df64c77ed5a9f8810b78e.setContent(html_b4b661c26630f87eff9a8fbf172aca34);
#
#
#
#         marker_e97aa1d2fc6b8584479cfc882c954821.bindPopup(popup_0cf21217bb6df64c77ed5a9f8810b78e)
#         ;
#
#
#
#
#             var marker_ce86768d0e59b4e401f3c8bd95359f1e = L.marker(
#                 [30.6880125, -81.90594389],
#                 {}
#             ).addTo(map_4fe3e63684907419c2d2a622ed19f835);
#
#
#         var popup_ea19d42b6b559ffc74783748d089cd3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e07af2f2b083c75ca56a3a735d0daf0c = $(`&lt;div id=&quot;html_e07af2f2b083c75ca56a3a735d0daf0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hilliard Airpark&lt;/div&gt;`)[0];
#                 popup_ea19d42b6b559ffc74783748d089cd3d.setContent(html_e07af2f2b083c75ca56a3a735d0daf0c);
#
#
#
#         marker_ce86768d0e59b4e401f3c8bd95359f1e.bindPopup(popup_ea19d42b6b559ffc74783748d089cd3d)
#         ;
#
#
#
#
#             var marker_2906e6c8dc1d5a51b36df

# %%
# multiple markers using dictionary

markers_dict = {'Los Angeles': [34.041008, -118.246653], 
                'Las Vegas': [36.169726, -115.143996], 
                'Denver': [39.739448, -104.992450], 
                'Chicago': [41.878765, -87.643267], 
                'Manhattan': [40.782949, -73.969559]}

# create map
map_cities = folium.Map(location=[41, -99], zoom_start=4)

# plot locations
for i in markers_dict.items():
    folium.Marker(location=i[1], popup=i[0]).add_to(map_cities)
    print(i)

# display map    
map_cities
# Out:
# ('Los Angeles', [34.041008, -118.246653])
# ('Las Vegas', [36.169726, -115.143996])
# ('Denver', [39.739448, -104.99245])
# ('Chicago', [41.878765, -87.643267])
# ('Manhattan', [40.782949, -73.969559])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11f368146082492a9116ec93f9d04c14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11f368146082492a9116ec93f9d04c14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11f368146082492a9116ec93f9d04c14 = L.map(
#                 &quot;map_11f368146082492a9116ec93f9d04c14&quot;,
#                 {
#                     center: [41.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7d8a603c73f5ad65114c01daa275726 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_d7d8a603c73f5ad65114c01daa275726.addTo(map_11f368146082492a9116ec93f9d04c14);
#
#             var marker_d5c31ac3ad8c7c52cd172cbc74621ef4 = L.marker(
#                 [34.041008, -118.246653],
#                 {}
#             ).addTo(map_11f368146082492a9116ec93f9d04c14);
#
#
#         var popup_beb603084326479d8920adf1d511fc5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8264d7d1ce5630f90fe67b95367f11fe = $(`&lt;div id=&quot;html_8264d7d1ce5630f90fe67b95367f11fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_beb603084326479d8920adf1d511fc5c.setContent(html_8264d7d1ce5630f90fe67b95367f11fe);
#
#
#
#         marker_d5c31ac3ad8c7c52cd172cbc74621ef4.bindPopup(popup_beb603084326479d8920adf1d511fc5c)
#         ;
#
#
#
#
#             var marker_667ed346dc5ba55f2af18426a28d6594 = L.marker(
#                 [36.169726, -115.143996],
#                 {}
#             ).addTo(map_11f368146082492a9116ec93f9d04c14);
#
#
#         var popup_ac78588523c51cdf2f0843e3b2bb1452 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77170e0076836316b8036f00e18a59ea = $(`&lt;div id=&quot;html_77170e0076836316b8036f00e18a59ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Las Vegas&lt;/div&gt;`)[0];
#                 popup_ac78588523c51cdf2f0843e3b2bb1452.setContent(html_77170e0076836316b8036f00e18a59ea);
#
#
#
#         marker_667ed346dc5ba55f2af18426a28d6594.bindPopup(popup_ac78588523c51cdf2f0843e3b2bb1452)
#         ;
#
#
#
#
#             var marker_d7489dbf7f9409cd9f46dff90cabf81b = L.marker(
#                 [39.739448, -104.99245],
#                 {}
#             ).addTo(map_11f368146082492a9116ec93f9d04c14);
#
#
#         var popup_7098c83440fe7fa22f36cc8f53b50000 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3346b328e0e372f37bccce23f2e23bf5 = $(`&lt;div id=&quot;html_3346b328e0e372f37bccce23f2e23bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[0];
#                 popup_7098c83440fe7fa22f36cc8f53b50000.setContent(html_3346b328e0e372f37bccce23f2e23bf5);
#
#
#
#         marker_d7489dbf7f9409cd9f46dff90cabf81b.bindPopup(popup_7098c83440fe7fa22f36cc8f53b50000)
#         ;
#
#
#
#
#             var marker_e8f93569d05c93a90d859ec56dc81b9f = L.marker(
#                 [41.878765, -87.643267],
#                 {}
#             ).addTo(map_11f368146082492a9116ec93f9d04c14);
#
#
#         var popup_3979a716dfbb5d22a0c4167c7c902624 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbdf123d5a73e498dc22c8d5cd06a137 = $(`&lt;div id=&quot;html_dbdf123d5a73e498dc22c8d5cd06a137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago&lt;/div&gt;`)[0];
#                 popup_3979a716dfbb5d22a0c4167c7c902624.setContent(html_dbdf123d5a73e498dc22c8d5cd06a137);
#
#
#
#         marker_e8f93569d05c93a90d859ec56dc81b9f.bindPopup(popup_3979a716dfbb5d22a0c4167c7c902624)
#         ;
#
#
#
#
#             var marker_13dfe791cbf28928dedc1be35992e455 = L.marker(
#                 [40.782949, -73.969559],
#                 {}
#             ).addTo(map_11f368146082492a9116ec93f9d04c14);
#
#
#         var popup_6297a0ff811efaaa18e2f2351e8c99b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f155379deb4522dab6c34609e1e2e5b1 = $(`&lt;div id=&quot;html_f155379deb4522dab6c34609e1e2e5b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#                 popup_6297a0ff811efaaa18e2f2351e8c99b8.setContent(html_f155379deb4522dab6c34609e1e2e5b1);
#
#
#
#         marker_13dfe791cbf28928dedc1be35992e455.bindPopup(popup_6297a0ff811efaaa18e2f2351e8c99b8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:

# %% [markdown]
# # Custom Markers

# %%
# search for 'font awesome' icons to see examples

# map
map_cm_fa = folium.Map(location=[38, -98], zoom_start=4)

# add custom marker to map
folium.Marker(location=[38, -98], 
              popup='popup', 
              icon=folium.Icon(color='green', icon='bolt', prefix='fa')).add_to(map_cm_fa)

# display map
map_cm_fa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc05fadf8e3223c8ad77856dbfeeb27c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc05fadf8e3223c8ad77856dbfeeb27c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc05fadf8e3223c8ad77856dbfeeb27c = L.map(
#                 &quot;map_cc05fadf8e3223c8ad77856dbfeeb27c&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab2d845cfb2e380afd77569192fb34ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ab2d845cfb2e380afd77569192fb34ac.addTo(map_cc05fadf8e3223c8ad77856dbfeeb27c);
#
#             var marker_ef94fee29d8b4349268ac32a643287dc = L.marker(
#                 [38.0, -98.0],
#                 {}
#             ).addTo(map_cc05fadf8e3223c8ad77856dbfeeb27c);
#
#
#             var icon_8f8fb10a2ad1046ce82837c045dd30cd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ef94fee29d8b4349268ac32a643287dc.setIcon(icon_8f8fb10a2ad1046ce82837c045dd30cd);
#
#
#         var popup_6cb861baaa1f72bd9a2b02d6824e79f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c938e89245a55b64fb6aa6f506a86e3 = $(`&lt;div id=&quot;html_8c938e89245a55b64fb6aa6f506a86e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#                 popup_6cb861baaa1f72bd9a2b02d6824e79f8.setContent(html_8c938e89245a55b64fb6aa6f506a86e3);
#
#
#
#         marker_ef94fee29d8b4349268ac32a643287dc.bindPopup(popup_6cb861baaa1f72bd9a2b02d6824e79f8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search for 'glyphicon bootstrap' icons to see examples

# map
map_cm_glyphicon = folium.Map(location=[38, -98], zoom_start=4)

# add custom marker to map
folium.Marker(location=[38, -98], 
              popup='popup', 
              icon=folium.Icon(icon='glyphicon-plane', prefix='glyphicon')).add_to(map_cm_glyphicon)

# display map
map_cm_glyphicon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c94b6167f8ff3ae0a6b6abb726d0533b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c94b6167f8ff3ae0a6b6abb726d0533b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c94b6167f8ff3ae0a6b6abb726d0533b = L.map(
#                 &quot;map_c94b6167f8ff3ae0a6b6abb726d0533b&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ae4d0afb345b66a259f9d0a1fa8b5fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_6ae4d0afb345b66a259f9d0a1fa8b5fe.addTo(map_c94b6167f8ff3ae0a6b6abb726d0533b);
#
#             var marker_91715bb8c08b442d64173ecb80d7589e = L.marker(
#                 [38.0, -98.0],
#                 {}
#             ).addTo(map_c94b6167f8ff3ae0a6b6abb726d0533b);
#
#
#             var icon_4ec579356c201d2a054c5a1a74af84cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91715bb8c08b442d64173ecb80d7589e.setIcon(icon_4ec579356c201d2a054c5a1a74af84cb);
#
#
#         var popup_b047c366f09ddee5ce8ae6b0d0e0ebb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_caeaf2c30c9115add6d238524aa4c68a = $(`&lt;div id=&quot;html_caeaf2c30c9115add6d238524aa4c68a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#                 popup_b047c366f09ddee5ce8ae6b0d0e0ebb6.setContent(html_caeaf2c30c9115add6d238524aa4c68a);
#
#
#
#         marker_91715bb8c08b442d64173ecb80d7589e.bindPopup(popup_b047c366f09ddee5ce8ae6b0d0e0ebb6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# multiple custom markers

# dataframe with custom marker names
cm_df = pd.DataFrame({'city': ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan'],
                      'latitude': [34.041008, 36.169726, 39.739448, 41.878765, 40.782949],
                      'longitude': [-118.246653, -115.143996, -104.992450, -87.643267, -73.969559],
                      'icon': ['bicycle', 'car', 'bus', 'truck', 'motorcycle']})
cm_df
# Out:
#           city   latitude   longitude        icon
# 0  Los Angeles  34.041008 -118.246653     bicycle
# 1    Las Vegas  36.169726 -115.143996         car
# 2       Denver  39.739448 -104.992450         bus
# 3      Chicago  41.878765  -87.643267       truck
# 4    Manhattan  40.782949  -73.969559  motorcycle

# %%
# map
map_cm_multiple = folium.Map(location=[38, -98], zoom_start=4)

# add markers to map
# for loop with itertuples (experiment that appears to work well)
# can also use iterrows or dataframe apply
for i in cm_df.itertuples():
    folium.Marker(location=[i.latitude, i.longitude], 
                  popup=i.city,
                  icon=folium.Icon(icon=i.icon, prefix='fa')).add_to(map_cm_multiple)

# display map    
map_cm_multiple
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07df35360c4f81b15c355a3e0c64858e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07df35360c4f81b15c355a3e0c64858e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07df35360c4f81b15c355a3e0c64858e = L.map(
#                 &quot;map_07df35360c4f81b15c355a3e0c64858e&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8a44c8f9c3df478a63996563d49ef0f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_e8a44c8f9c3df478a63996563d49ef0f.addTo(map_07df35360c4f81b15c355a3e0c64858e);
#
#             var marker_defd7a1e4ec4fe9f47c12935c1ca0873 = L.marker(
#                 [34.041008, -118.246653],
#                 {}
#             ).addTo(map_07df35360c4f81b15c355a3e0c64858e);
#
#
#             var icon_5a2914136600907aa9bd2b633d80ca9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_defd7a1e4ec4fe9f47c12935c1ca0873.setIcon(icon_5a2914136600907aa9bd2b633d80ca9f);
#
#
#         var popup_aac3309146ac3175df2b26b9d0916503 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff437f0e234bddf021268f4a75afd59a = $(`&lt;div id=&quot;html_ff437f0e234bddf021268f4a75afd59a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_aac3309146ac3175df2b26b9d0916503.setContent(html_ff437f0e234bddf021268f4a75afd59a);
#
#
#
#         marker_defd7a1e4ec4fe9f47c12935c1ca0873.bindPopup(popup_aac3309146ac3175df2b26b9d0916503)
#         ;
#
#
#
#
#             var marker_9de33ba031e2615d5ebecf8f8cf82a4e = L.marker(
#                 [36.169726, -115.143996],
#                 {}
#             ).addTo(map_07df35360c4f81b15c355a3e0c64858e);
#
#
#             var icon_fa20827b714aa3611933bd38dad60391 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9de33ba031e2615d5ebecf8f8cf82a4e.setIcon(icon_fa20827b714aa3611933bd38dad60391);
#
#
#         var popup_0325017a90aaa141c4de5273cef6fc60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3df0e76b4a4d4a1770dbc552a7c73d5 = $(`&lt;div id=&quot;html_a3df0e76b4a4d4a1770dbc552a7c73d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Las Vegas&lt;/div&gt;`)[0];
#                 popup_0325017a90aaa141c4de5273cef6fc60.setContent(html_a3df0e76b4a4d4a1770dbc552a7c73d5);
#
#
#
#         marker_9de33ba031e2615d5ebecf8f8cf82a4e.bindPopup(popup_0325017a90aaa141c4de5273cef6fc60)
#         ;
#
#
#
#
#             var marker_7b9c24a6ed94bd88b3e67b7de3be2ca9 = L.marker(
#                 [39.739448, -104.99245],
#                 {}
#             ).addTo(map_07df35360c4f81b15c355a3e0c64858e);
#
#
#             var icon_76cdfd4b3b5fc43915db585de1192189 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7b9c24a6ed94bd88b3e67b7de3be2ca9.setIcon(icon_76cdfd4b3b5fc43915db585de1192189);
#
#
#         var popup_b4c3c87c0c423ec4507651dd498b0c39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_760c72f39fb8e22e5384a0d0a510d77b = $(`&lt;div id=&quot;html_760c72f39fb8e22e5384a0d0a510d77b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[0];
#                 popup_b4c3c87c0c423ec4507651dd498b0c39.setContent(html_760c72f39fb8e22e5384a0d0a510d77b);
#
#
#
#         marker_7b9c24a6ed94bd88b3e67b7de3be2ca9.bindPopup(popup_b4c3c87c0c423ec4507651dd498b0c39)
#         ;
#
#
#
#
#             var marker_d23b1e4249e0254b21b3ca1768e857fc = L.marker(
#                 [41.878765, -87.643267],
#                 {}
#             ).addTo(map_07df35360c4f81b15c355a3e0c64858e);
#
#
#             var icon_cd9ed97a5a666cbce620212ad2a14c9d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %%
for i in cm_df.itertuples():
    print(i)
    # print(i.city)
# Out:
# Pandas(Index=0, city='Los Angeles', latitude=34.041008, longitude=-118.246653, icon='bicycle')
# Pandas(Index=1, city='Las Vegas', latitude=36.169726, longitude=-115.143996, icon='car')
# Pandas(Index=2, city='Denver', latitude=39.739448, longitude=-104.99245, icon='bus')
# Pandas(Index=3, city='Chicago', latitude=41.878765, longitude=-87.643267, icon='truck')
# Pandas(Index=4, city='Manhattan', latitude=40.782949, longitude=-73.969559, icon='motorcycle')

# %%
# enumerate markers

# data
cm_enum_df = pd.DataFrame({'city': ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan'],
                           'latitude': [34.041008, 36.169726, 39.739448, 41.878765, 40.782949],
                           'longitude': [-118.246653, -115.143996, -104.992450, -87.643267, -73.969559],
                           'icon_num': [1, 2, 3, 4, 5]})

# map
map_enum_icons = folium.Map([38, -98], zoom_start=4)

# icons using plugins.BeautifyIcon
for i in cm_enum_df.itertuples():
    folium.Marker(location=[i.latitude, i.longitude],
                  popup=i.city,
                  icon=plugins.BeautifyIcon(number=i.icon_num,
                                            border_color='blue',
                                            border_width=1,
                                            text_color='red',
                                            inner_icon_style='margin-top:0px;')).add_to(map_enum_icons)

# display map    
map_enum_icons
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c45e19ee65ccda9505b47b271c370ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c45e19ee65ccda9505b47b271c370ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c45e19ee65ccda9505b47b271c370ac = L.map(
#                 &quot;map_7c45e19ee65ccda9505b47b271c370ac&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18c66c7499a359804a6c7a2b05c731e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_18c66c7499a359804a6c7a2b05c731e7.addTo(map_7c45e19ee65ccda9505b47b271c370ac);
#
#             var marker_3054167c8e3f026277beffa43aea59e4 = L.marker(
#                 [34.041008, -118.246653],
#                 {}
#             ).addTo(map_7c45e19ee65ccda9505b47b271c370ac);
#
#
#             var beautify_icon_7d56e9a0096dc8d1ae33978e3a13f52f = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;blue&quot;, &quot;borderWidth&quot;: 1, &quot;innerIconStyle&quot;: &quot;margin-top:0px;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 1, &quot;textColor&quot;: &quot;red&quot;}
#             )
#             marker_3054167c8e3f026277beffa43aea59e4.setIcon(beautify_icon_7d56e9a0096dc8d1ae33978e3a13f52f);
#
#
#         var popup_0c80282548c27518ee79c77ed6dd6cdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19dc79d567685966551289c9a09fd655 = $(`&lt;div id=&quot;html_19dc79d567685966551289c9a09fd655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_0c80282548c27518ee79c77ed6dd6cdc.setContent(html_19dc79d567685966551289c9a09fd655);
#
#
#
#         marker_3054167c8e3f026277beffa43aea59e4.bindPopup(popup_0c80282548c27518ee79c77ed6dd6cdc)
#         ;
#
#
#
#
#             var marker_229b6ac7803bedeea95cf9467ff8a127 = L.marker(
#                 [36.169726, -115.143996],
#                 {}
#             ).addTo(map_7c45e19ee65ccda9505b47b271c370ac);
#
#
#             var beautify_icon_179377ab3d2421d17be06ba5fe32585c = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;blue&quot;, &quot;borderWidth&quot;: 1, &quot;innerIconStyle&quot;: &quot;margin-top:0px;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 2, &quot;textColor&quot;: &quot;red&quot;}
#             )
#             marker_229b6ac7803bedeea95cf9467ff8a127.setIcon(beautify_icon_179377ab3d2421d17be06ba5fe32585c);
#
#
#         var popup_b0a1560fed21cea7c1944ba428950969 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_216fcdcb34342d09226060c9afc0fe14 = $(`&lt;div id=&quot;html_216fcdcb34342d09226060c9afc0fe14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Las Vegas&lt;/div&gt;`)[0];
#                 popup_b0a1560fed21cea7c1944ba428950969.setContent(html_216fcdcb34342d09226060c9afc0fe14);
#
#
#
#         marker_229b6ac7803bedeea95cf9467ff8a127.bindPopup(popup_b0a1560fed21cea7c1944ba428950969)
#         ;
#
#
#
#
#             var marker_d6306f4ff906f73129603aacf25cf29e = L.marker(
#                 [39.739448, -104.99245],
#                 {}
#             ).addTo(map_7c45e19ee65ccda9505b47b271c370ac);
#
#
#             var beautify_icon_2c2458b8c86b0adc041a395a442a42ce = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;blue&quot;, &quot;borderWidth&quot;: 1, &quot;innerIconStyle&quot;: &quot;margin-top:0px;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 3, &quot;textColor&quot;: &quot;red&quot;}
#             )
#             marker_d6306f4ff906f73129603aacf25cf29e.setIcon(beautify_icon_2c2458b8c86b0adc041a395a442a42ce);
#
#
#         var popup_8f928a22ee4b3023e435c2aaf7352a41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae74628712c9a66d7cf095c4229ba036 = $(`&lt;div id=&quot;html_ae74628712c9a66d7cf095c4229ba036&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[

# %%
cm_enum_df
# Out:
#           city   latitude   longitude  icon_num
# 0  Los Angeles  34.041008 -118.246653         1
# 1    Las Vegas  36.169726 -115.143996         2
# 2       Denver  39.739448 -104.992450         3
# 3      Chicago  41.878765  -87.643267         4
# 4    Manhattan  40.782949  -73.969559         5

# %% [markdown]
# # Circle Markers

# %%
# map
map_circle = folium.Map(location=[38, -98], zoom_start=4)

# radius of the circle in meters
folium.Circle(radius=10000, location=[38, -98], color='green').add_to(map_circle)

# circle of a fixed size with radius specified in pixels
folium.CircleMarker(location=[39, -105], radius=25, color='blue', fill_color='yellow').add_to(map_circle)

# display map
map_circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb6c5d9012079acb289ca76637ad8f1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb6c5d9012079acb289ca76637ad8f1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb6c5d9012079acb289ca76637ad8f1a = L.map(
#                 &quot;map_fb6c5d9012079acb289ca76637ad8f1a&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65f8d8679a2a3de6483d0e17759082d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_65f8d8679a2a3de6483d0e17759082d4.addTo(map_fb6c5d9012079acb289ca76637ad8f1a);
#
#             var circle_68176c26e9339ea00f3220af147b9915 = L.circle(
#                 [38.0, -98.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fb6c5d9012079acb289ca76637ad8f1a);
#
#
#             var circle_marker_c8aeaac7afa5acec7d16f42a3a119ad3 = L.circleMarker(
#                 [39.0, -105.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fb6c5d9012079acb289ca76637ad8f1a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Plot Route

# %%
# route

# map
map_plot_route = folium.Map(location=[38, -98], zoom_start=4)

# route_locs = ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan']
# can use list of lists or list of tuples
route_lats_longs = [[34.041008,-118.246653],
                    [36.169726,-115.143996], 
                    [39.739448,-104.992450], 
                    [41.878765,-87.643267], 
                    [40.782949,-73.969559]]

# add route to map
folium.PolyLine(route_lats_longs).add_to(map_plot_route)

# display map
map_plot_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d579ac844cba314e6b9541e4dfc2bff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d579ac844cba314e6b9541e4dfc2bff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d579ac844cba314e6b9541e4dfc2bff = L.map(
#                 &quot;map_5d579ac844cba314e6b9541e4dfc2bff&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e51a27e99cd10d5a2d777a5245ccee8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_2e51a27e99cd10d5a2d777a5245ccee8.addTo(map_5d579ac844cba314e6b9541e4dfc2bff);
#
#             var poly_line_7db8bb3cfbb7179bfb79018d3a09c264 = L.polyline(
#                 [[34.041008, -118.246653], [36.169726, -115.143996], [39.739448, -104.99245], [41.878765, -87.643267], [40.782949, -73.969559]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5d579ac844cba314e6b9541e4dfc2bff);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ant path route
# uses import - from folium import plugins

# map
map_ant_route = folium.Map(location=[38, -98], zoom_start=4)

# add ant path route to map
plugins.AntPath(route_lats_longs).add_to(map_ant_route)

# display map
map_ant_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_827658c356e43ec8a69cd4465f69a102 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_827658c356e43ec8a69cd4465f69a102&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_827658c356e43ec8a69cd4465f69a102 = L.map(
#                 &quot;map_827658c356e43ec8a69cd4465f69a102&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fa0a50213ac73f4a0c9a6e480eda510 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_2fa0a50213ac73f4a0c9a6e480eda510.addTo(map_827658c356e43ec8a69cd4465f69a102);
#
#             ant_path_22874ab7735c1e89c174fe3356737b4d = L.polyline.antPath(
#               [[34.041008, -118.246653], [36.169726, -115.143996], [39.739448, -104.99245], [41.878765, -87.643267], [40.782949, -73.969559]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: [10, 20], &quot;dashOffset&quot;: null, &quot;delay&quot;: 400, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_827658c356e43ec8a69cd4465f69a102);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
